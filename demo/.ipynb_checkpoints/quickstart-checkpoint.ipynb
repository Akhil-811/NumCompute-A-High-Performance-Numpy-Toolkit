# %% [markdown]
# # NumCompute: End-to-End Machine Learning Framework
#
# > Developed as part of Assignment 2.1 — Machine Learning Framework Implementation
#
# This notebook demonstrates a modular machine learning framework built from scratch using NumPy.
#
# ### Features Covered
# - CSV Data Loading (with missing values)
# - Data Preprocessing (Imputer, Scaling, Encoding)
# - Sorting & Searching Algorithms
# - Ranking & Percentiles
# - Statistical Analysis
# - Evaluation Metrics
# - Gradient & Jacobian Estimation
# - Pipeline Abstraction
# - Performance Benchmarking

# %%
import numpy as np

from numcompute.io import read_csv
from numcompute.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder, Imputer
from numcompute.sort_search import top_k, quickselect, binary_search
from numcompute.rank import rank_with_ties, percentile
from numcompute.stats import RunningStats, histogram, quantiles
from numcompute.metrics import accuracy, precision, recall, f1_score, mse, confusion_matrix, roc_auc
from numcompute.optim import finite_diff_grad, jacobian
from numcompute.pipeline import Pipeline, FeatureUnion
from numcompute.benchmarking import benchmark
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
# ----> 3 from numcompute.io import read_csv
#       4 from numcompute.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder, Imputer
#       5 from numcompute.sort_search import top_k, quickselect, binary_search
#
# ModuleNotFoundError: No module named 'numcompute'

# %% [markdown]
# ## 1. Data Loading
#
# We load CSV data using a custom streaming reader that supports:
# - Missing values (NaNs)
# - Chunk-based loading
# - Flexible delimiters

# %%
with open("data.csv", "w") as f:
    f.write("1,2,\n3,,6\n7,8,9\n")

data = next(read_csv("data.csv"))
print("Raw Data:\n", data)

# %% [markdown]
# ## 2. Data Preprocessing
#
# We clean and normalize the data using:
# - Imputer → replaces missing values
# - StandardScaler → z-score normalization
# - MinMaxScaler → range scaling
# - OneHotEncoder → categorical encoding

# %%
pipe = Pipeline([
    ("imputer", Imputer()),
    ("scaler", StandardScaler())
])

X_processed = pipe.fit(data).transform(data)
print("Processed Data:\n", X_processed)

# %%
mm = MinMaxScaler().fit(data)
print("MinMax Scaled:\n", mm.transform(data))

# %%
cat = np.array([[1],[2],[1],[3]])
ohe = OneHotEncoder().fit(cat)
print("OneHot:\n", ohe.transform(cat))

# %% [markdown]
# ## 3. Sorting & Searching
#
# We demonstrate:
# - Sorting
# - Top-K selection
# - Quickselect
# - Binary search

# %%
arr = np.array([5,1,9,3,7])

print("Sorted:", np.sort(arr))
print("Top-3 indices:", top_k(arr, 3))
print("Quickselect (k=2):", quickselect(arr, 2))

sorted_arr = np.sort(arr)
print("Binary search (7):", binary_search(sorted_arr, 7))

# %% [markdown]
# ## 4. Ranking & Percentiles
#
# We compute ranks while handling ties and derive percentiles.

# %%
x = np.array([10, 20, 20, 40])

print("Ranks:", rank_with_ties(x))
print("Percentiles:", percentile(x))

# %% [markdown]
# ## 5. Statistical Analysis
#
# We compute:
# - Mean & variance
# - Histogram
# - Quantiles
# - Streaming statistics

# %%
print("Mean:", np.mean(X_processed, axis=0))
print("Std:", np.std(X_processed, axis=0))

print("Histogram:", histogram(X_processed[:,0], bins=3))
print("Quantiles:", quantiles(X_processed[:,0], [25,50,75]))

rs = RunningStats()
rs.update(X_processed[:,0])

print("Running Mean:", rs.mean)
print("Running Variance:", rs.variance())

# %% [markdown]
# ## 6. Evaluation Metrics

# %%
y_true = np.array([1,0,1,1])
y_pred = np.array([1,0,0,1])
y_scores = np.array([0.9,0.2,0.4,0.8])

print("Accuracy:", accuracy(y_true, y_pred))
print("Precision:", precision(y_true, y_pred))
print("Recall:", recall(y_true, y_pred))
print("F1:", f1_score(y_true, y_pred))
print("MSE:", mse(y_true, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_true, y_pred))
print("ROC AUC:", roc_auc(y_true, y_scores))

# %% [markdown]
# ## 7. Gradient & Jacobian Estimation

# %%
def f(x):
    return x[0]**2 + x[1]**2

def F(x):
    return np.array([x[0] + x[1], x[0]*x[1]])

x = np.array([2.0, 3.0])

print("Gradient:", finite_diff_grad(f, x))
print("Jacobian:\n", jacobian(F, x))

# %% [markdown]
# ## 8. Pipeline & FeatureUnion

# %%
fu = FeatureUnion([
    ("scale1", StandardScaler()),
    ("scale2", StandardScaler())
])

fu.fit(data)
print("FeatureUnion:\n", fu.transform(data))

# %% [markdown]
# ## 9. Performance Benchmarking

# %%
def vectorised(x):
    return np.sum(x**2)

def loop(x):
    s = 0
    for i in x:
        s += i*i
    return s

x = np.random.rand(1000000)

t_vec = benchmark(vectorised, x)
t_loop = benchmark(loop, x)

print("Vectorised:", t_vec)
print("Loop:", t_loop)

# %%
print("\nPerformance Comparison")
print("----------------------")
print(f"Vectorised Time: {t_vec:.6f}s")
print(f"Loop Time:       {t_loop:.6f}s")
print(f"Speedup:         {t_loop/t_vec:.2f}x")

# %% [markdown]
# ## 10. Conclusion
#
# This notebook demonstrates a complete ML framework with:
#
# - Modular architecture
# - Efficient NumPy vectorization
# - Clean API design
# - End-to-end pipeline
#
# ### Key Takeaways
# - Vectorization significantly improves performance
# - Modular design enhances scalability
# - Numerical stability is crucial
#
# ---
